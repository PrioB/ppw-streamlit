# %% [markdown]
# ### Prio Budi Laksono
# ### 210411100063
# ### PPW A

# %%
import string
import pandas as pd
import numpy as np

# %% [markdown]
# ### Scraping website IDNtimes

# %%
import requests
from bs4 import BeautifulSoup
import csv

# URL dari artikel sepak bola di IDN Times
url = 'https://www.idntimes.com/sport/arena/yogama-wisnu-oktyandito/jadwal-kapolri-cup-2024-babak-8-besar-hingga-final'

# Membuat permintaan ke URL
response = requests.get(url)

# Inisialisasi data yang akan disimpan
# Mengambil ulang dan membersihkan data yang diminta
artikel_mees = []

if response.status_code == 200:
    # Parsing halaman web
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Mengambil judul artikel
    title = soup.find('h1').get_text().strip()
    
    # Mengambil tanggal publikasi artikel dan membersihkan spasi berlebih
    date = soup.find('time').get_text().strip()
    
    # Mengambil isi artikel dengan membersihkan konten tambahan
    content = soup.find_all('p')
    article_text = '\n'.join([p.get_text().strip() for p in content if p.get_text().strip()])

    # Simpan data dalam bentuk dictionary yang telah dibersihkan
    artikel_mees.append({
        'Title': title,
        'Date': date,
        'Content': article_text
    })

# Membuat dataframe dari data yang telah dibersihkan
data_mees = pd.DataFrame(artikel_mees)

# Menampilkan dataframe yang bersih
data_mees
# Out:
#                                                Title               Date  \
# 0  Daftar Lengkap Komisi DPR RI Beserta Fungsi da...  10 Oct 24 | 06:00
#
#                                              Content
# 0  Regional\nKategori\nEvent\nDOWNLOAD IDN APP SE...

# %% [markdown]
# ### Mengukur kemiripan antar teks

# %%
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Proases Case holding
# mengubah ke huruf kecil

# %%
# Proses case folding
def casefolding(Content):
    if isinstance(Content, list):
        # Jika Content adalah list, terapkan case folding pada setiap elemen
        return [str(item).lower() for item in Content]
    else:
        # Jika Content adalah string, langsung terapkan case folding
        return str(Content).lower()

# Terapkan fungsi casefolding pada kolom 'Content'
data_mees['Content'] = data_mees['Content'].apply(casefolding)

data_mees.head()
# Out:
#                                                Title               Date  \
# 0  Daftar Lengkap Komisi DPR RI Beserta Fungsi da...  10 Oct 24 | 06:00
#
#                                              Content
# 0  regional\nkategori\nevent\ndownload idn app se...

# %% [markdown]
# ### menyimpan kedalam dataframe ke csv

# %%
csv_filename = "artikel_mees_hilgers.csv"
data_mees.to_csv(csv_filename, index=False, encoding='utf-8')

print(f"Data berita telah disimpan ke {csv_filename}")
# Out:
# Data berita telah disimpan ke artikel_mees_hilgers.csv

# %%
data_mees = pd.read_csv("artikel_mees_hilgers.csv", sep=',', encoding='latin1')
data_mees.head()
# Out:
#                                                Title               Date  \
# 0  Daftar Lengkap Komisi DPR RI Beserta Fungsi da...  10 Oct 24 | 06:00
#
#                                              Content
# 0  regional\nkategori\nevent\ndownload idn app se...

# %% [markdown]
# ### cleansing content

# %%
def cleansing(Content):
    # Menghapus whitespace di awal dan akhir teks
    Content = Content.strip()
    
    # Menghapus tanda baca dan karakter khusus
    Content = re.sub(f"[{string.punctuation}]", '', Content)
    
    # Menghapus angka
    Content = re.sub(r'\d+', '', Content)
    
    # Menghapus huruf tunggal (opsional, tergantung kebutuhan)
    Content = re.sub(r"\b[a-zA-Z]\b", "", Content)
    
    # Menghapus karakter-karakter non-standar seperti â
    Content = re.sub(r'[^\x00-\x7F]+', '', Content)
    
    # Menghapus spasi ganda
    Content = re.sub(r'\s+', ' ', Content)
    
    return Content

# Terapkan fungsi cleansing pada kolom 'Content'
data_mees['Content'] = data_mees['Content'].apply(cleansing)

# Menampilkan 5 baris pertama
data_mees.head(5)
# Out:
#                                                Title               Date  \
# 0  Daftar Lengkap Komisi DPR RI Beserta Fungsi da...  10 Oct 24 | 06:00
#
#                                              Content
# 0  regional kategori event download idn app sekar...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pblak\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Tokenisasi

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
import pandas as pd  # Ensure you import pandas for DataFrame usage

# Download required resources
nltk.download('punkt')
nltk.download('punkt_tab')

# Assume article_text is defined; replace with your actual text
# article_text = "Your article text goes here."

# Ekstraksi kalimat dari konten artikel
sentences = sent_tokenize(article_text)

# Tokenisasi tiap kalimat menjadi term
terms_per_sentence = [word_tokenize(sentence) for sentence in sentences]

# Membuat objek yang menyimpan hasil term dari setiap kalimat
extracted_terms = [{'Sentence': sentence, 'Terms': terms} for sentence, terms in zip(sentences, terms_per_sentence)]

# Menampilkan hasilnya sebagai dataframe
df_terms = pd.DataFrame(extracted_terms)

# Menampilkan dataframe
print(df_terms)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pblak\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\pblak\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
#                                              Sentence  \
# 0   Regional\nKategori\nEvent\nDOWNLOAD IDN APP SE...
# 1   Jakarta, IDN Times - Anggota Dewan Perwakilan ...
# 2   Rencana yang akan direalisasikan pada pekan de...
# 3   Langkah ini diambil untuk mengakomodasi strukt...
# 4   Mantan Ketua Badan Urusan Rumah Tangga (BURT) ...
# ..                                                ...
# 64  Mereka juga berperan dalam mendorong kebijakan...
# 65  Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah ...
# 66  Mereka bertanggung jawab memantau pengelolaan ...
# 67  Dalam bidang keuangan, Komisi XI mengawasi sek...
# 68  Mereka bekerja dengan mitra seperti Otoritas J...
#
#                                                 Terms
# 0   [Regional, Kategori, Event, DOWNLOAD, IDN, APP...
# 1   [Jakarta, ,, IDN, Times, -, Anggota, Dewan, Pe...
# 2   [Rencana, yang, akan, direalisasikan, pada, pe...
# 3   [Langkah, ini, diambil, untuk, mengakomodasi, ...
# 4   [Mantan, Ketua, Badan, Urusan, Rumah, Tangga, ...
# ..                                                ...
# 64  [Mereka, juga, berperan, dalam, mendorong, keb...
# 65  [Baca, Juga, :, Pimpinan, DPR, 2024-2029, Dapa...
# 66  [Mereka, bertanggung, jawab, memantau, pengelo...
# 67  [Dalam, bidang, keuangan, ,, Komisi, XI, menga...
# 68  [Mereka, bekerja, dengan, mitra, seperti, Otor...
#
# [69 rows x 2 columns]

# %% [markdown]
# ### menyimpan DataFrame df_terms ke dalam file CSV bernama "artikel_mees_hilgers_ekstract_term.csv" tanpa menyertakan indeks baris, dan menggunakan encoding UTF-8.

# %%
csv_filename = "artikel_mees_hilgers_ekstract_term.csv"
df_terms.to_csv(csv_filename, index=False, encoding='utf-8')

print(f"Data berita telah disimpan ke {csv_filename}")
# Out:
# Data berita telah disimpan ke artikel_mees_hilgers_ekstract_term.csv

# %% [markdown]
# ### menghitung dan menampilkan TF-IDF

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import sent_tokenize, word_tokenize

# Assuming we have the article_text
sentences = sent_tokenize(article_text)
terms_per_sentence = [word_tokenize(sentence) for sentence in sentences]
extracted_terms = [{'Sentence': sentence, 'Terms': terms} for sentence, terms in zip(sentences, terms_per_sentence)]
df_terms = pd.DataFrame(extracted_terms)

# Menggabungkan terms menjadi string untuk setiap kalimat
df_terms['Terms_String'] = df_terms['Terms'].apply(' '.join)

# Membuat TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit dan transform data
tfidf_matrix = tfidf_vectorizer.fit_transform(df_terms['Terms_String'])

# Mendapatkan nama-nama feature (terms)
feature_names = tfidf_vectorizer.get_feature_names_out()

# Membuat DataFrame untuk nilai TF-IDF
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

# Menambahkan kolom Sentence
tfidf_df['Sentence'] = df_terms['Sentence']

# Melelehkan (melting) DataFrame untuk format yang lebih mudah dibaca
melted_tfidf = tfidf_df.melt(id_vars=['Sentence'], var_name='Term', value_name='TF-IDF')

# Menghapus baris dengan nilai TF-IDF 0
melted_tfidf = melted_tfidf[melted_tfidf['TF-IDF'] != 0]

# Mengurutkan berdasarkan nilai TF-IDF tertinggi
melted_tfidf = melted_tfidf.sort_values('TF-IDF', ascending=False)

# Menampilkan hasil
print(melted_tfidf)
# Out:
#                                                 Sentence        Term    TF-IDF
# 27655  Mereka juga mengawasi implementasi undang-unda...      undang  0.821898
# 14357                                 "Memang 13 komisi.      memang  0.717322
# 27621  Mereka bertanggung jawab mengawasi proses legi...      undang  0.712887
# 12926  Mereka juga berperan dalam mendorong ratifikas...    konvensi  0.689860
# 19242  Mereka bertanggung jawab mengawasi implementas...  pendidikan  0.682544
# ...                                                  ...         ...       ...
# 4500   Mereka mengawasi pelaksanaan kebijakan otonomi...         dan  0.061448
# 12454  Komisi V bekerja sama dengan berbagai kementer...      komisi  0.060535
# 4488   Langkah ini diambil untuk mengakomodasi strukt...         dan  0.059164
# 4524   Selain itu, Komisi V juga bekerja sama dengan ...         dan  0.058294
# 4507   Dalam bidang HAM, Komisi III bertugas memantau...         dan  0.049516
#
# [1090 rows x 3 columns]

# %% [markdown]
# ### menghitung kemiripan antar kalimat berdasarkan cosine similarity dari vektor TF-IDF setiap kalimat dalam artikel

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import cosine

# Assuming we have the melted_tfidf DataFrame from the previous code
# If not, uncomment and run the previous code to get melted_tfidf

# Step 1: Pivot the melted DataFrame back to wide format
tfidf_wide = melted_tfidf.pivot(index='Sentence', columns='Term', values='TF-IDF').fillna(0)

# Step 2: Calculate cosine similarity between sentences
num_sentences = len(tfidf_wide)
adjacency_matrix = np.zeros((num_sentences, num_sentences))

for i in range(num_sentences):
    for j in range(i, num_sentences):  # We only need to calculate upper triangle
        if i == j:
            adjacency_matrix[i][j] = 1.0  # Sentence is fully similar to itself
        else:
            similarity = 1 - cosine(tfidf_wide.iloc[i], tfidf_wide.iloc[j])
            adjacency_matrix[i][j] = similarity
            adjacency_matrix[j][i] = similarity  # Matrix is symmetric

# Create a DataFrame for better visualization
adjacency_df = pd.DataFrame(adjacency_matrix, 
                            index=tfidf_wide.index, 
                            columns=tfidf_wide.index)

# Display the adjacency matrix
print("Adjacency Matrix:")
print(adjacency_df)

# Optional: You can set a threshold to consider only strong connections
threshold = 0.05
adjacency_df_thresholded = adjacency_df.where(adjacency_df > threshold, 0)

print("\nAdjacency Matrix (with threshold):")
print(adjacency_df_thresholded)

# Optional: Save to CSV
adjacency_df.to_csv('adjacency_matrix.csv')
adjacency_df_thresholded.to_csv('adjacency_matrix_thresholded.csv')
# Out:
# Adjacency Matrix:
# Sentence                                            "Memang 13 komisi.  \
# Sentence
# "Memang 13 komisi.                                            1.000000
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...            0.018413
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...            0.020018
# Berikut daftar lengkap komisi DPR RI periode 20...            0.047538
# Dalam bidang HAM, Komisi III bertugas memantau ...            0.015462
# ...                                                                ...
# Terkait kependudukan, Komisi IX bertanggung jaw...            0.026104
# Terkait lingkungan hidup, Komisi VII bertanggun...            0.029093
# Terkait pariwisata, pemuda, dan olahraga, Komis...            0.019965
# Terkait pemberdayaan perempuan, Komisi VIII ber...            0.025341
# Tugas Komisi V juga mencakup mitigasi bencana d...            0.033107
#
# Sentence                                            Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Kalibata Digerogoti Tikus dan Rayap\nKomisi IV DPR RI memiliki tanggung jawab besar dalam mengawal ketahanan pangan dan pengelolaan sumber daya alam Indonesia.  \
# Sentence
# "Memang 13 komisi.                                                                           0.018413
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           1.000000
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.277353
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.086657
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.017287
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.131773
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.081950
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.036954
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.046904
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.044452
#
# Sentence                                            Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah Dinas, Bukan Tunjangan Perumahan\nTerakhir, Komisi XI DPR RI memiliki peran vital dalam mengawasi kebijakan ekonomi dan keuangan negara.  \
# Sentence
# "Memang 13 komisi.                                                                           0.020018
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.277353
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           1.000000
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.135109
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.046163
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.049373
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.049054
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.025314
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.047930
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.041530
#
# Sentence                                            Berikut daftar lengkap komisi DPR RI periode 2019-2024 yang berjumlah 11 komisi, beserta fungsi dan tugasnya.  \
# Sentence
# "Memang 13 komisi.                                                                           0.047538
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.086657
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.135109
# Berikut daftar lengkap komisi DPR RI periode 20...                                           1.000000
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.038050
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.033968
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.030766
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.025980
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.068537
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.035011
#
# Sentence                                            Dalam bidang HAM, Komisi III bertugas memantau dan mengevaluasi kasus-kasus pelanggaran HAM, serta mengawasi kinerja lembaga-lembaga negara yang berkaitan dengan penegakan HAM, seperti Komnas HAM.  \
# Sentence
# "Memang 13 komisi.                                                                           0.015462
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.017287
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.046163
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.038050
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           1.000000
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.025566
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.023880
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.019553
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.047952
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.014012
#
# Sentence                                            Dalam bidang investasi, Komisi VI bertugas memantau iklim investasi dan implementasi kebijakan kemudahan berusaha.  \
# Sentence
# "Memang 13 komisi.                                                                           0.027735
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.031009
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.045309
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.029330
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.097798
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.049792
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.091994
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.020836
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.048337
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.025135
#
# Sentence                                            Dalam bidang kebudayaan, Komisi X bertugas memantau upaya pelestarian dan pengembangan budaya nasional.  \
# Sentence
# "Memang 13 komisi.                                                                           0.034249
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.038292
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.034598
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.036219
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.120767
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.033641
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.027275
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.106789
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.032658
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.031038
#
# Sentence                                            Dalam bidang kelautan dan perikanan, Komisi IV bertanggung jawab mengawasi pengelolaan sumber daya laut, termasuk pemberantasan illegal fishing dan pengembangan industri perikanan nasional.  \
# Sentence
# "Memang 13 komisi.                                                                           0.021268
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.187419
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.036797
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.027675
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.047838
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.192512
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.139579
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.123848
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.093306
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.026494
#
# Sentence                                            Dalam bidang ketenagakerjaan, Komisi IX bertugas memantau kebijakan dan program terkait perlindungan tenaga kerja, pengupahan, dan peningkatan keterampilan tenaga kerja.  \
# Sentence
# "Memang 13 komisi.                                                                           0.021647
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.032377
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.039807
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.028168
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.079763
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.202904
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.118796
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.045392
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.147114
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.075446
#
# Sentence                                            Dalam bidang keuangan, Komisi XI mengawasi sektor keuangan, termasuk kebijakan perpajakan, kebijakan moneter, dan pelaksanaan anggaran negara.  \
# Sentence
# "Memang 13 komisi.                                                                           0.025629
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.028654
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.275277
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.027103
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.082499
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.084050
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.086027
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.072960
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.081593
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.023226
#
# Sentence                                            ...  \
# Sentence                                            ...
# "Memang 13 komisi.                                  ...
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...  ...
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...  ...
# Berikut daftar lengkap komisi DPR RI periode 20...  ...
# Dalam bidang HAM, Komisi III bertugas memantau ...  ...
# ...                                                 ...
# Terkait kependudukan, Komisi IX bertanggung jaw...  ...
# Terkait lingkungan hidup, Komisi VII bertanggun...  ...
# Terkait pariwisata, pemuda, dan olahraga, Komis...  ...
# Terkait pemberdayaan perempuan, Komisi VIII ber...  ...
# Tugas Komisi V juga mencakup mitigasi bencana d...  ...
#
# Sentence                                            Rencana yang akan direalisasikan pada pekan depan ini disebut mencakup penambahan jumlah komisi dari 11 menjadi 13, serta peningkatan jumlah badan di DPR menjadi tujuh.  \
# Sentence
# "Memang 13 komisi.                                                                           0.144487
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.049075
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.038600
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.102721
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.043816
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.038472
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.008659
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.005942
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.033557
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.104182
#
# Sentence                                            Selain itu, Komisi V juga bekerja sama dengan badan-badan perindustrian seperti Badan Koordinasi Penanaman Modal (BKPM) dan Badan Perlindungan Konsumen Nasional (BPKN).  \
# Sentence
# "Memang 13 komisi.                                                                           0.018203
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.024441
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.022835
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.019250
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.048780
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.017880
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.053139
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.033842
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.051017
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.037766
#
# Sentence                                            Selain itu, mereka juga bekerja sama dengan rumah sakit negeri, pemerintah provinsi dan BUMN.  \
# Sentence
# "Memang 13 komisi.                                                                           0.000000
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.078829
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.079918
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.006865
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.036239
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.015078
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.008402
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.011532
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.014637
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.042467
#
# Sentence                                            Terkait kehutanan, Komisi IV bertugas memantau pengelolaan hutan secara berkelanjutan, termasuk upaya konservasi dan rehabilitasi hutan.  \
# Sentence
# "Memang 13 komisi.                                                                           0.023503
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.094763
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.012878
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.024854
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.053027
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.051854
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.100673
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.039660
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.050339
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.021299
#
# Sentence                                            Terkait kepemiluan, Komisi II bertanggung jawab mengawasi penyelenggaraan pemilu dan pilkada.  \
# Sentence
# "Memang 13 komisi.                                                                           0.033805
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.049804
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.035922
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.035749
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.027748
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.176053
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.186127
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.134651
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.170908
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.030635
#
# Sentence                                            Terkait kependudukan, Komisi IX bertanggung jawab mengawasi kebijakan dan program pengendalian pertumbuhan penduduk dan peningkatan kualitas sumber daya manusia.  \
# Sentence
# "Memang 13 komisi.                                                                           0.026104
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.131773
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.049373
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.033968
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.025566
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           1.000000
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.175167
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.114666
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.205200
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.090979
#
# Sentence                                            Terkait lingkungan hidup, Komisi VII bertanggung jawab mengawasi implementasi kebijakan perlindungan dan pengelolaan lingkungan.  \
# Sentence
# "Memang 13 komisi.                                                                           0.029093
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.081950
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.049054
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.030766
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.023880
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.175167
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           1.000000
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.115883
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.223844
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.026365
#
# Sentence                                            Terkait pariwisata, pemuda, dan olahraga, Komisi X bertanggung jawab mengawasi pengembangan sektor pariwisata nasional, pemberdayaan pemuda, dan pembinaan prestasi olahraga.  \
# Sentence
# "Memang 13 komisi.                                                                           0.019965
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.036954
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.025314
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.025980
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.019553
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.114666
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.115883
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           1.000000
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.166148
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.024872
#
# Sentence                                            Terkait pemberdayaan perempuan, Komisi VIII bertanggung jawab mengawasi kebijakan dan program yang mendukung kesetaraan gender dan perlindungan perempuan.  \
# Sentence
# "Memang 13 komisi.                                                                           0.025341
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.046904
# ...
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.051854
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.100673
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.000000
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.050339
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.000000
#
# Sentence                                            Terkait kepemiluan, Komisi II bertanggung jawab mengawasi penyelenggaraan pemilu dan pilkada.  \
# Sentence
# "Memang 13 komisi.                                                                           0.000000
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.000000
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.000000
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.000000
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.000000
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.176053
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.186127
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.134651
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.170908
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.000000
#
# Sentence                                            Terkait kependudukan, Komisi IX bertanggung jawab mengawasi kebijakan dan program pengendalian pertumbuhan penduduk dan peningkatan kualitas sumber daya manusia.  \
# Sentence
# "Memang 13 komisi.                                                                           0.000000
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.131773
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.000000
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.000000
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.000000
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           1.000000
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.175167
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.114666
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.205200
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.090979
#
# Sentence                                            Terkait lingkungan hidup, Komisi VII bertanggung jawab mengawasi implementasi kebijakan perlindungan dan pengelolaan lingkungan.  \
# Sentence
# "Memang 13 komisi.                                                                           0.000000
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.081950
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.000000
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.000000
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.000000
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.175167
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           1.000000
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.115883
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.223844
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.000000
#
# Sentence                                            Terkait pariwisata, pemuda, dan olahraga, Komisi X bertanggung jawab mengawasi pengembangan sektor pariwisata nasional, pemberdayaan pemuda, dan pembinaan prestasi olahraga.  \
# Sentence
# "Memang 13 komisi.                                                                           0.000000
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.000000
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.000000
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.000000
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.000000
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.114666
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.115883
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           1.000000
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.166148
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.000000
#
# Sentence                                            Terkait pemberdayaan perempuan, Komisi VIII bertanggung jawab mengawasi kebijakan dan program yang mendukung kesetaraan gender dan perlindungan perempuan.  \
# Sentence
# "Memang 13 komisi.                                                                           0.000000
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.000000
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.000000
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.068537
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.000000
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.205200
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.223844
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.166148
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           1.000000
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           0.000000
#
# Sentence                                            Tugas Komisi V juga mencakup mitigasi bencana dan peningkatan infrastruktur publik.
# Sentence
# "Memang 13 komisi.                                                                           0.000000
# Baca Juga: Anggota DPR Ngeluh Rumah Dinas di Ka...                                           0.000000
# Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah D...                                           0.000000
# Berikut daftar lengkap komisi DPR RI periode 20...                                           0.000000
# Dalam bidang HAM, Komisi III bertugas memantau ...                                           0.000000
# ...                                                                                               ...
# Terkait kependudukan, Komisi IX bertanggung jaw...                                           0.090979
# Terkait lingkungan hidup, Komisi VII bertanggun...                                           0.000000
# Terkait pariwisata, pemuda, dan olahraga, Komis...                                           0.000000
# Terkait pemberdayaan perempuan, Komisi VIII ber...                                           0.000000
# Tugas Komisi V juga mencakup mitigasi bencana d...                                           1.000000
#
# [69 rows x 69 columns]

# %% [markdown]
# ### membangun dan memvisualisasikan graf kalimat berdasarkan kemiripan (cosine similarity)

# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
import textwrap

# Assuming we have the tfidf_wide DataFrame and original sentences from previous steps
# If not, you need to run the TF-IDF calculation code first

# Calculate cosine similarity
cosine_sim = cosine_similarity(tfidf_wide)

# Create a DataFrame for the similarity matrix
similarity_df = pd.DataFrame(cosine_sim, index=tfidf_wide.index, columns=tfidf_wide.index)

# Create a graph from the similarity matrix
G = nx.from_pandas_adjacency(similarity_df)

# Remove self-loops
G.remove_edges_from(nx.selfloop_edges(G))

# Function to get the largest connected component
def get_largest_component(G):
    return max(nx.connected_components(G), key=len)

# Ensure the graph is connected
while not nx.is_connected(G):
    largest_component = get_largest_component(G)
    isolated_nodes = set(G.nodes()) - set(largest_component)
    if not isolated_nodes:
        break
    for node in isolated_nodes:
        similarities = [(other_node, similarity_df.loc[node, other_node]) 
                        for other_node in largest_component]
        most_similar_node = max(similarities, key=lambda x: x[1])[0]
        G.add_edge(node, most_similar_node)

# Function to wrap text
def wrap_text(text, width=20):
    return '\n'.join(textwrap.wrap(text, width=width))

# Prepare labels (wrapped sentences)
labels = {node: wrap_text(node) for node in G.nodes()}

# Now let's visualize the graph
plt.figure(figsize=(20, 16))  # Increased figure size
pos = nx.spring_layout(G, k=0.5, iterations=50)

# Calculate node sizes based on degree centrality
degree_centrality = nx.degree_centrality(G)
node_sizes = [v * 10000 for v in degree_centrality.values()]  # Increased node sizes

# Draw the graph
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color='lightblue')
nx.draw_networkx_edges(G, pos, alpha=0.3)

# Add labels
nx.draw_networkx_labels(G, pos, labels, font_size=6)  # Reduced font size

plt.title("Connected Sentence Similarity Graph")
plt.axis('off')
plt.tight_layout()

# Save the graph as an image
plt.savefig('connected_sentence_similarity_graph.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# Print some information about the graph
print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
print(f"Is the graph connected? {nx.is_connected(G)}")

# Calculate centrality measures
closeness_centrality = nx.closeness_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)

# Create a DataFrame with centrality measures
centrality_data = []
for node in G.nodes():
    centrality_data.append({
        'Sentence': node,
        'Degree Centrality': degree_centrality[node],
        'Closeness Centrality': closeness_centrality[node],
        'Betweenness Centrality': betweenness_centrality[node]
    })

centrality_df = pd.DataFrame(centrality_data)

# Sort by Degree Centrality
centrality_df = centrality_df.sort_values('Degree Centrality', ascending=False)

print("\nCentrality Measures:")
print(centrality_df)

# Save centrality measures to CSV
centrality_df.to_csv('centrality_measures_with_sentences.csv', index=False)

# Optionally, print the top 5 sentences by each centrality measure
print("\nTop 5 sentences by Degree Centrality:")
print(centrality_df.nlargest(5, 'Degree Centrality')[['Sentence', 'Degree Centrality']])

print("\nTop 5 sentences by Closeness Centrality:")
print(centrality_df.nlargest(5, 'Closeness Centrality')[['Sentence', 'Closeness Centrality']])

print("\nTop 5 sentences by Betweenness Centrality:")
print(centrality_df.nlargest(5, 'Betweenness Centrality')[['Sentence', 'Betweenness Centrality']])
# Out:
# Number of nodes: 69
# Number of edges: 2108
# Is the graph connected? True
#
# Centrality Measures:
#                                              Sentence  Degree Centrality  \
# 1   Baca Juga: Anggota DPR Ngeluh Rumah Dinas di K...           0.985294
# 4   Dalam bidang HAM, Komisi III bertugas memantau...           0.985294
# 2   Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah ...           0.985294
# 8   Dalam bidang ketenagakerjaan, Komisi IX bertug...           0.985294
# 5   Dalam bidang investasi, Komisi VI bertugas mem...           0.985294
# ..                                                ...                ...
# 49  Mereka juga mengawasi implementasi undang-unda...           0.691176
# 31  Mantan Ketua Badan Urusan Rumah Tangga (BURT) ...           0.647059
# 0                                  "Memang 13 komisi.           0.573529
# 16  Jakarta, IDN Times - Anggota Dewan Perwakilan ...           0.573529
# 58  Regional\nKategori\nEvent\nDOWNLOAD IDN APP SE...           0.014706
#
#     Closeness Centrality  Betweenness Centrality
# 1               0.985507                0.002188
# 4               0.985507                0.002188
# 2               0.985507                0.002188
# 8               0.985507                0.002188
# 5               0.985507                0.002188
# ..                   ...                     ...
# 49              0.755556                0.000149
# 31              0.739130                0.000610
# 0               0.693878                0.000000
# 16              0.701031                0.029758
# 58              0.414634                0.000000
#
# [69 rows x 4 columns]
#
# Top 5 sentences by Degree Centrality:
#                                             Sentence  Degree Centrality
# 1  Baca Juga: Anggota DPR Ngeluh Rumah Dinas di K...           0.985294
# 4  Dalam bidang HAM, Komisi III bertugas memantau...           0.985294
# 2  Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah ...           0.985294
# 8  Dalam bidang ketenagakerjaan, Komisi IX bertug...           0.985294
# 5  Dalam bidang investasi, Komisi VI bertugas mem...           0.985294
#
# Top 5 sentences by Closeness Centrality:
#                                             Sentence  Closeness Centrality
# 1  Baca Juga: Anggota DPR Ngeluh Rumah Dinas di K...              0.985507
# 4  Dalam bidang HAM, Komisi III bertugas memantau...              0.985507
# 2  Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah ...              0.985507
# 8  Dalam bidang ketenagakerjaan, Komisi IX bertug...              0.985507
# 5  Dalam bidang investasi, Komisi VI bertugas mem...              0.985507
#
# Top 5 sentences by Betweenness Centrality:
#                                              Sentence  Betweenness Centrality
# 16  Jakarta, IDN Times - Anggota Dewan Perwakilan ...                0.029758
# 1   Baca Juga: Anggota DPR Ngeluh Rumah Dinas di K...                0.002188
# 4   Dalam bidang HAM, Komisi III bertugas memantau...                0.002188
# 2   Baca Juga: Pimpinan DPR 2024-2029 Dapat Rumah ...                0.002188
# 8   Dalam bidang ketenagakerjaan, Komisi IX bertug...                0.002188
