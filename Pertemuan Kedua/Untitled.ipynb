# %%
pip install -U jupyter-book
# Out:
# ...
#    ---------------------------------------- 0.0/3.4 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.4 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.4 MB 2.6 MB/s eta 0:00:02
#    ------------ --------------------------- 1.0/3.4 MB 2.3 MB/s eta 0:00:02
#    ------------------ --------------------- 1.6/3.4 MB 2.1 MB/s eta 0:00:01
#    ------------------------ --------------- 2.1/3.4 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 2.6/3.4 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------ --- 3.1/3.4 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.4/3.4 MB 2.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 2.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 2.6 MB/s eta 0:00:01
# ...

# %%
mkdir my_jupyter_book
cd my_jupyter_book
# Out:
#   Cell In[1], line 1
#     mkdir my_jupyter_book
#           ^
# SyntaxError: invalid syntax
